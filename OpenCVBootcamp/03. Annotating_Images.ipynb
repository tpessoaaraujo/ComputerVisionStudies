# %%
# %pip install opencv-python
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (9.0, 9.0)
from IPython.display import Image

# %%
# Lendo uma imagem
image = cv2.imread("assets/Apollo_11_Launch.jpg", cv2.IMREAD_COLOR)

# Imprimindo a imagem original convertida para RGB
plt.imshow(image[:,:,::-1])

# %%
imageLine = image.copy()

# A linha começa em (200, 100) e termina em (400, 100)
# A cor da linha é AMARELA e a espessura é de 5 pixels
# Linetype é cv2.Line_AA
cv2.line(imageLine, (200, 100), (400, 100), (0, 255, 255), thickness=5, lineType=cv2.LINE_AA)

# Imprimindo a imagem com a linha
plt.imshow(imageLine[:,:,::-1])

# %%
# Desenhando um circúlo
imageCircle = image.copy()
cv2.circle(imageCircle, (900, 500), 100, (0, 0, 255), thickness=5, lineType=cv2.LINE_AA)

# Imprimindo a imagem com o círculo
plt.imshow(imageCircle[:,:,::-1])

# %%
# Desenhando um retângulo
imageRectangle = image.copy()
cv2.rectangle(imageRectangle, (500, 100), (700, 600), (255, 0, 255), thickness=5, lineType=cv2.LINE_8)

# Imprimindo a imagem com o retângulo
plt.imshow(imageRectangle[:,:,::-1])

# %%
# Adicionando textos a imagem
imageText = image.copy()
text = "Apollo 11 Saturn V Launch, July 16, 1969"
fontScale = 2.3
fontFace = cv2.FONT_HERSHEY_PLAIN
fontColor = (0, 255, 0)
fontThickness = 2

cv2.putText(imageText, text, (200, 700), fontFace, fontScale, fontColor, fontThickness)

# Imprimindo a imagem com o texto
plt.imshow(imageText[:,:,::-1])
