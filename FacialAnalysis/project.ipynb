# %%
# %pip install numpy==1.26.4
# %pip install opencv-python==4.10.0.84
# %pip install opencv-contrib-python==4.10.0.84
# %pip install mediapipe
# Out:
# Requirement already satisfied: numpy==1.26.4 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python==4.10.0.84 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from opencv-python==4.10.0.84) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from opencv-contrib-python==4.10.0.84) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mediapipe in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (0.10.21)
# Requirement already satisfied: absl-py in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (25.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (25.9.23)
# Requirement already satisfied: jax in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: jaxlib in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (0.7.1)
# Requirement already satisfied: matplotlib in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (3.10.7)
# Requirement already satisfied: numpy<2 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (0.5.3)
# Requirement already satisfied: sentencepiece in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from mediapipe) (0.2.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.23)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from jax->mediapipe) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\thiago araujo\desktop\facialanalysis\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp

# %%
mp_face = mp.solutions.face_mesh
mp_drawing = mp.solutions.drawing_utils

face = mp_face.FaceMesh()

# %%
cam = cv2.VideoCapture(0)
resolution_x, resolution_y = 1280, 720

cam.set(cv2.CAP_PROP_FRAME_WIDTH, resolution_x)
cam.set(cv2.CAP_PROP_FRAME_HEIGHT, resolution_y)

while True:
    success, frame = cam.read()
    
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    result = face.process(frame_rgb)
    
    if result.multi_face_landmarks:
        try:
            for face_landmarks in result.multi_face_landmarks:
                mp_drawing.draw_landmarks(frame, face_landmarks, mp_face.FACEMESH_CONTOURS,
                    landmark_drawing_spec = mp_drawing.DrawingSpec(color=(255,102,102), thickness=1, circle_radius=1),
                    connection_drawing_spec = mp_drawing.DrawingSpec(color=(102,204,0), thickness=1, circle_radius=1))
        except:
            pass
            
    cv2.imshow("Webcam", frame)
    
    if cv2.waitKey(10) & 0xFF == 27:
        break

cam.release()
cv2.destroyAllWindows()
